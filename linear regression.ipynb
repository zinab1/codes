# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
num_puntos = 100
conjunto_puntos = []
for i in range(num_puntos):
    x1= np.random.normal(0.0, 0.55)
    y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
    conjunto_puntos.append([x1, y1])
    
    
x_data = [v[0] for v in conjunto_puntos]
y_data = [v[1] for v in conjunto_puntos]

plt.plot(x_data, y_data, 'ro', label='Original data')
plt.legend()
plt.show()

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b
loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
for step in range(20):
    print(step, sess.run(W), sess.run(b))
    sess.run(train)
# Out:
# 0 [-0.83364964] [0.]
# 1 [-0.56333333] [0.12813225]
# 2 [-0.36375046] [0.17658125]
# 3 [-0.2246646] [0.21235262]
# 4 [-0.1273782] [0.23728108]
# 5 [-0.05934583] [0.25471777]
# 6 [-0.01177006] [0.26691127]
# 7 [0.02150017] [0.2754383]
# 8 [0.04476639] [0.28140137]
# 9 [0.06103669] [0.28557137]
# 10 [0.07241467] [0.28848752]
# 11 [0.08037142] [0.2905268]
# 12 [0.08593565] [0.29195288]
# 13 [0.08982677] [0.29295018]
# 14 [0.09254788] [0.2936476]
# 15 [0.09445077] [0.29413527]
# 16 [0.09578148] [0.29447633]
# 17 [0.09671207] [0.29471484]
# 18 [0.09736283] [0.29488164]
# 19 [0.09781792] [0.2949983]

# %%
sess.run(init)
for step in range(50):
    sess.run(train)
    print(step, sess.run(W), sess.run(b))
    y_pred_value=sess.run(y)
    plt.plot(x_data, y_data,'go', x_data, y_pred_value, 'ro')
    w_value=sess.run(W)
    b_value=sess.run(b)
    text="$ {} x + {}$".format(w_value, b_value)
    plt.text(-1, .4, text)

    plt.show()
# Out:
# 0 [-0.34996483] [0.18666257]
# 1 [-0.21385056] [0.21482342]
# 2 [-0.11986973] [0.23921928]
# 3 [-0.05409262] [0.25606352]
# 4 [-0.00809654] [0.2678528]
# 5 [0.02406911] [0.2760967]
# 6 [0.04656287] [0.28186178]
# 7 [0.06229298] [0.28589335]
# 8 [0.07329321] [0.28871268]
# 9 [0.08098578] [0.29068425]
# 10 [0.08636528] [0.292063]
# 11 [0.09012722] [0.29302716]
# 12 [0.09275798] [0.29370144]
# 13 [0.0945977] [0.29417294]
# 14 [0.09588423] [0.29450268]
# 15 [0.09678392] [0.29473326]
# 16 [0.09741308] [0.29489452]
# 17 [0.09785306] [0.2950073]
# 18 [0.09816074] [0.29508615]
# 19 [0.0983759] [0.29514128]
# 20 [0.09852637] [0.29517984]
# 21 [0.09863159] [0.29520682]
# 22 [0.09870517] [0.29522568]
# 23 [0.09875663] [0.29523885]
# 24 [0.09879262] [0.2952481]
# 25 [0.09881779] [0.29525453]
# 26 [0.09883538] [0.29525906]
# 27 [0.09884769] [0.2952622]
# 28 [0.09885629] [0.2952644]
# 29 [0.09886231] [0.29526594]
# 30 [0.09886652] [0.29526702]
# 31 [0.09886947] [0.2952678]
# 32 [0.09887152] [0.2952683]
# 33 [0.09887296] [0.29526868]
# 34 [0.09887397] [0.29526892]
# 35 [0.09887467] [0.2952691]
# 36 [0.09887516] [0.29526925]
# 37 [0.09887551] [0.29526934]
# 38 [0.09887575] [0.2952694]
# 39 [0.09887592] [0.29526943]
# 40 [0.09887604] [0.29526946]
# 41 [0.09887612] [0.2952695]
# 42 [0.09887618] [0.2952695]
# 43 [0.09887622] [0.29526952]
# 44 [0.09887625] [0.29526952]
# 45 [0.09887627] [0.29526952]
# 46 [0.09887628] [0.29526952]
# 47 [0.09887628] [0.29526952]
# 48 [0.09887629] [0.29526952]
# 49 [0.0988763] [0.29526952]
